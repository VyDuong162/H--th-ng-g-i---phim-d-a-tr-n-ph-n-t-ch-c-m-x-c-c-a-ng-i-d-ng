# %% [markdown]
# <a href="https://colab.research.google.com/github/VyDuong162/Movie-recommendation-system-base-on-sentiment-analysis/blob/main/preprocessing3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path_dir = '/content/drive/MyDrive/LV/RecommenderSYS/datasets'

# %% [markdown]
# ## Task 1: Extracting movies data

# %% [markdown]
# -  ### Subtask 1.1: Import and read 2018 movies from Wikipedia

# %%
link="https://en.wikipedia.org/wiki/List_of_American_films_of_2018"
df1 = pd.read_html(link)[2]
df2 = pd.read_html(link)[3]
df3 = pd.read_html(link)[4]
df4 = pd.read_html(link)[5]

# %%
data_18 = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
data_18
# Out:
#       Opening  Opening.1                       Title  \
# 0     JANUARY          5     Insidious: The Last Key
# 1     JANUARY          5            The Strange Ones
# 2     JANUARY          5                    Stratton
# 3     JANUARY         10               Sweet Country
# 4     JANUARY         12                The Commuter
# ..        ...        ...                         ...
# 267  DECEMBER         25             Holmes & Watson
# 268  DECEMBER         25                        Vice
# 269  DECEMBER         25         On the Basis of Sex
# 270  DECEMBER         25                   Destroyer
# 271  DECEMBER         28  Black Mirror: Bandersnatch
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2                                    Momentum Pictures
# 3                                 Samuel Goldwyn Films
# ...

# %%
# !pip install tmdbv3api

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '1974662aed9fdffb3ac0d19b14b68349'
from tmdbv3api import Movie
tmdb_movie = Movie()

# %%
Movie().search('Stratton')
# Out:
# [{'adult': False, 'backdrop_path': '/A1h8T4gIVwQFomMUaMF7Yah7K9R.jpg', 'genre_ids': [28, 53], 'id': 348389, 'original_language': 'en', 'original_title': 'Stratton', 'overview': 'A British Special Boat Service commando tracks down an international terrorist cell.', 'popularity': 19.661, 'poster_path': '/mibBHS9mVV2z5rdeFdOkH94Sw1c.jpg', 'release_date': '2017-07-06', 'title': 'Stratton', 'video': False, 'vote_average': 5, 'vote_count': 173},
#  {'adult': False, 'backdrop_path': '/A9cz3ZrsrFT7NgTZNgYevHIfjwF.jpg', 'genre_ids': [18, 10749], 'id': 43440, 'original_language': 'en', 'original_title': 'The Stratton Story', 'overview': 'Star major league pitcher Monty Stratton loses a leg in a hunting accident, but becomes determined to leave the game on his own terms.', 'popularity': 3.118, 'poster_path': '/lAEyw8xDCvXY9qsEZCrP2btqatv.jpg', 'release_date': '1949-05-12', 'title': 'The Stratton Story', 'video': False, 'vote_average': 6.8, 'vote_count': 24},
# ...

# %%
#function get genre from api tmdb
def get_genre(x):
  genres = []
  result = tmdb_movie.search(x)
  if not result:
      return np.NaN
  else:
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
      genres_str = " "
      for i in range(0, len(data_json['genres'])):
          genres.append(data_json['genres'][i]['name'])
      return genres_str.join(genres)
    else:
      return np.NaN

# %%
get_genre('Stratton')
# Out:
# 'Action Thriller'

# %%
data_18['genres'] = data_18['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2018 = data_18[['Title','Cast and crew','genres']]

# %%
df_2018
# Out:
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 267             Holmes & Watson
# 268                        Vice
# 269         On the Basis of Sex
# 270                   Destroyer
# 271  Black Mirror: Bandersnatch
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 267  Etan Cohen (director/screenplay); Will Ferrell...
# 268  Adam McKay (director/screenplay); Christian Ba...
# 269  Mimi Leder (director); Daniel Stiepleman (scre...
# ...

# %%
df_2018['Cast and crew'][0]
# Out:
# 'Adam Robitel (director); Leigh Whannell (screenplay); Lin Shaye, Angus Sampson, Leigh Whannell, Spencer Locke, Caitlin Gerard, Kirk Acevedo, Bruce Davison'

# %%
# function get director
def get_director(x):
  if " (director)" in x:
    return x.split(" (director)")[0]
  elif " (directors)" in x:
    return x.split(" (directors)")[0]
  else:
    return x.split(" (director/screenplay)")[0]

# %%
director = df_2018['Cast and crew'].map(lambda x: get_director(x))

# %%
df_2018['director_name'] = director
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor(x):
  return ((x.split("screenplay); ")[-1]).split(", "))[:3]

# %%
get_actor(df_2018['Cast and crew'][2])[0]
# Out:
# 'Dominic Cooper'

# %%
actors = df_2018['Cast and crew'].map(lambda x: get_actor(x))

# %%
actors = pd.DataFrame(actors.to_list(), columns=['actor_1_name','actor_2_name','actor_3_name'])

# %%
actors
# Out:
#         actor_1_name            actor_2_name    actor_3_name
# 0          Lin Shaye           Angus Sampson  Leigh Whannell
# 1      Alex Pettyfer  James Freedson-Jackson   Emily Althaus
# 2     Dominic Cooper          Austin Stowell      Gemma Chan
# 3        Bryan Brown               Sam Neill            None
# 4        Liam Neeson            Vera Farmiga  Patrick Wilson
# ..               ...                     ...             ...
# 267     Will Ferrell          John C. Reilly    Rebecca Hall
# 268   Christian Bale               Amy Adams    Steve Carell
# 269   Felicity Jones            Armie Hammer  Justin Theroux
# 270    Nicole Kidman          Sebastian Stan    Toby Kebbell
# 271  Fionn Whitehead            Will Poulter   Asim Chaudhry
#
# [272 rows x 3 columns]

# %%
df_2018 = pd.merge(df_2018, actors, left_index=True, right_index=True)

# %%
df_2018
# Out:
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 267             Holmes & Watson
# 268                        Vice
# 269         On the Basis of Sex
# 270                   Destroyer
# 271  Black Mirror: Bandersnatch
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 267  Etan Cohen (director/screenplay); Will Ferrell...
# 268  Adam McKay (director/screenplay); Christian Ba...
# 269  Mimi Leder (director); Daniel Stiepleman (scre...
# ...

# %%
df_2018['actor_1_name'][0].strip()
# Out:
# 'Lin Shaye'

# %%
round(df_2018.isnull().sum().sort_values(ascending=False)/len(df_2018)*100,2)
# Out:
# actor_3_name     9.93
# actor_2_name     3.68
# genres           0.74
# Title            0.00
# Cast and crew    0.00
# director_name    0.00
# actor_1_name     0.00
# dtype: float64

# %%
(df_2018.isnull().sum(axis=1).sort_values(ascending=False) >=2).sum()
# Out:
# 10

# %%
df_2018['genres'] = df_2018['genres'].fillna('')

# %%
round(df_2018.isnull().sum().sort_values(ascending=False)/len(df_2018)*100,2)
# Out:
# actor_3_name     9.93
# actor_2_name     3.68
# Title            0.00
# Cast and crew    0.00
# genres           0.00
# director_name    0.00
# actor_1_name     0.00
# dtype: float64

# %%
df_2018['Title'] = df_2018['Title'].str.lower()

# %%
df_2018 = df_2018.rename(columns={'Title':'movie_title'})

# %%
new_df18 = df_2018.loc[:,['movie_title','director_name', 'genres','actor_1_name', 'actor_2_name','actor_3_name']]

# %%
new_df18['comb'] = new_df18['director_name'] +' ' + new_df18['genres']+' '+ new_df18['actor_1_name'] + ' ' + new_df18['actor_2_name'] + ' '+ new_df18['actor_3_name']

# %%
new_df18
# Out:
#                     movie_title       director_name  \
# 0       insidious: the last key        Adam Robitel
# 1              the strange ones    Lauren Wolkstein
# 2                      stratton          Simon West
# 3                 sweet country    Warwick Thornton
# 4                  the commuter  Jaume Collet-Serra
# ..                          ...                 ...
# 267             holmes & watson          Etan Cohen
# 268                        vice          Adam McKay
# 269         on the basis of sex          Mimi Leder
# 270                   destroyer        Karyn Kusama
# 271  black mirror: bandersnatch         David Slade
#
#                                               genres     actor_1_name  \
# 0                            Horror Mystery Thriller        Lin Shaye
# 1                                     Thriller Drama    Alex Pettyfer
# 2                                    Action Thriller   Dominic Cooper
# ...

# %% [markdown]
# -  ### Subtask 1.2: Import and read 2019 movies from Wikipedia

# %%
link="https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
df1 = pd.read_html(link)[2]
df2 = pd.read_html(link)[3]
df3 = pd.read_html(link)[4]
df4 = pd.read_html(link)[5]

# %%
data_19 = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
data_19
# Out:
#       Opening  Opening.1              Title  \
# 0     JANUARY          4        Escape Room
# 1     JANUARY          4         Rust Creek
# 2     JANUARY          4   American Hangman
# 3     JANUARY         11   A Dog's Way Home
# 4     JANUARY         11         The Upside
# ..        ...        ...                ...
# 237  DECEMBER         25  Spies in Disguise
# 238  DECEMBER         25       Little Women
# 239  DECEMBER         25               1917
# 240  DECEMBER         25         Just Mercy
# 241  DECEMBER         27           Clemency
#
#                                     Production company  \
# 0                    Columbia Pictures / Original Film
# 1                                            IFC Films
# 2                          Hangman Justice Productions
# 3                                    Columbia Pictures
# 4                                    STX Entertainment
# ..                                                 ...
# ...

# %%
data_19['genres'] = data_19['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2019 = data_19[['Title','Cast and crew','genres']]

# %%
# function get director
def get_director(x):
  if " (director)" in x:
    return x.split(" (director)")[0]
  elif " (directors)" in x:
    return x.split(" (directors)")[0]
  else:
    return x.split(" (director/screenplay)")[0]

# %%
director = df_2019['Cast and crew'].map(lambda x: get_director(x))

# %%
get_actor(df_2019['Cast and crew'][2])[0]
# Out:
# 'Donald Sutherland'

# %%
df_2019
# Out:
#                  Title                                      Cast and crew  \
# 0          Escape Room  Adam Robitel (director); Bragi F. Schut, Maria...
# 1           Rust Creek  Jen McGowan (director); Julie Lipson (screenpl...
# 2     American Hangman  Wilson Coneybeare (director/screenplay); Donal...
# 3     A Dog's Way Home  Charles Martin Smith (director); W. Bruce Came...
# 4           The Upside  Neil Burger (director); Jon Hartmere (screenpl...
# ..                 ...                                                ...
# 237  Spies in Disguise  Nick Bruno, Troy Quane (directors); Brad Copel...
# 238       Little Women  Greta Gerwig (director/screenplay); Saoirse Ro...
# 239               1917  Sam Mendes (director/screenplay); Krysty Wilso...
# 240         Just Mercy  Destin Daniel Cretton (director/screenplay), A...
# 241           Clemency  Chinonye Chukwu (director/screenplay); Alfre W...
#
#                                        genres
# ...

# %%
actors = df_2019['Cast and crew'].map(lambda x: get_actor(x))

# %%
actors = pd.DataFrame(actors.to_list(), columns=['actor_1_name','actor_2_name','actor_3_name'])

# %%
actors
# Out:
#             actor_1_name          actor_2_name      actor_3_name
# 0         Taylor Russell          Logan Miller  Deborah Ann Woll
# 1      Hermione Corfield           Jay Paulson      Sean O'Bryan
# 2      Donald Sutherland    Vincent Kartheiser     Oliver Dennis
# 3    Bryce Dallas Howard    Edward James Olmos   Alexandra Shipp
# 4         Bryan Cranston            Kevin Hart     Nicole Kidman
# ..                   ...                   ...               ...
# 237           Will Smith           Tom Holland     Rashida Jones
# 238        Saoirse Ronan           Emma Watson     Florence Pugh
# 239        George MacKay  Dean-Charles Chapman       Mark Strong
# 240    Michael B. Jordan            Jamie Foxx       Brie Larson
# 241        Alfre Woodard        Wendell Pierce       Aldis Hodge
#
# [242 rows x 3 columns]

# %%
df_2019['director_name'] = director
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2019 = pd.merge(df_2019, actors, left_index=True, right_index=True)

# %%
df_2019['actor_1_name'][0].strip()
# Out:
# 'Taylor Russell'

# %%
round(df_2019.isnull().sum().sort_values(ascending=False)/len(df_2019)*100,2)
# Out:
# actor_3_name     6.20
# actor_2_name     0.41
# Title            0.00
# Cast and crew    0.00
# genres           0.00
# director_name    0.00
# actor_1_name     0.00
# dtype: float64

# %%
df_2019.dropna(how='any',inplace=True)

# %%
df_2019
# Out:
#                  Title                                      Cast and crew  \
# 0          Escape Room  Adam Robitel (director); Bragi F. Schut, Maria...
# 1           Rust Creek  Jen McGowan (director); Julie Lipson (screenpl...
# 2     American Hangman  Wilson Coneybeare (director/screenplay); Donal...
# 3     A Dog's Way Home  Charles Martin Smith (director); W. Bruce Came...
# 4           The Upside  Neil Burger (director); Jon Hartmere (screenpl...
# ..                 ...                                                ...
# 237  Spies in Disguise  Nick Bruno, Troy Quane (directors); Brad Copel...
# 238       Little Women  Greta Gerwig (director/screenplay); Saoirse Ro...
# 239               1917  Sam Mendes (director/screenplay); Krysty Wilso...
# 240         Just Mercy  Destin Daniel Cretton (director/screenplay), A...
# 241           Clemency  Chinonye Chukwu (director/screenplay); Alfre W...
#
#                                        genres           director_name  \
# ...

# %%
df_2019['Title'] = df_2019['Title'].str.lower()

# %%
df_2019 = df_2019.rename(columns={'Title':'movie_title'})

# %%
new_df19 = df_2019.loc[:,['movie_title','director_name', 'genres','actor_1_name', 'actor_2_name','actor_3_name']]

# %%
new_df19['comb'] = new_df19['director_name'] +' ' + new_df19['genres']+' '+ new_df19['actor_1_name'] + ' ' + new_df19['actor_2_name'] + ' '+ new_df19['actor_3_name']

# %% [markdown]
# ## Task 2: Gather 2018 and 2019 movies data

# %%
my_df = new_df18.append(new_df19,ignore_index=True)

# %%
my_df
# Out:
#                  movie_title           director_name  \
# 0    insidious: the last key            Adam Robitel
# 1           the strange ones        Lauren Wolkstein
# 2                   stratton              Simon West
# 3              sweet country        Warwick Thornton
# 4               the commuter      Jaume Collet-Serra
# ..                       ...                     ...
# 494        spies in disguise  Nick Bruno, Troy Quane
# 495             little women            Greta Gerwig
# 496                     1917              Sam Mendes
# 497               just mercy   Destin Daniel Cretton
# 498                 clemency         Chinonye Chukwu
#
#                                        genres       actor_1_name  \
# 0                     Horror Mystery Thriller          Lin Shaye
# 1                              Thriller Drama      Alex Pettyfer
# 2                             Action Thriller     Dominic Cooper
# ...

# %%
old_df = pd.read_csv(path_dir+'/'+'new_data.csv')

# %%
old_df
# Out:
#                                      movie_title          director_name  \
# 0                                         avatar          James Cameron
# 1       pirates of the caribbean: at world's end         Gore Verbinski
# 2                                        spectre             Sam Mendes
# 3                          the dark knight rises      Christopher Nolan
# 4     star wars: episode vii - the force awakens            Doug Walker
# ...                                          ...                    ...
# 5356                the incredible jessica james            Jim Strouse
# 5357                           can't buy my love            Farhad Mann
# 5358            thick lashes of lauri mäntyvaara       Hannaleena Hauru
# 5359                 cop and a half: new recruit  Jonathan A. Rosenbaum
# 5360                                         mom           Ravi Udyawar
#
#                                genres          actor_1_name  \
# ...

# %%
final_df = old_df.append(my_df,ignore_index=True)

# %%
final_df
# Out:
#                                      movie_title           director_name  \
# 0                                         avatar           James Cameron
# 1       pirates of the caribbean: at world's end          Gore Verbinski
# 2                                        spectre              Sam Mendes
# 3                          the dark knight rises       Christopher Nolan
# 4     star wars: episode vii - the force awakens             Doug Walker
# ...                                          ...                     ...
# 5855                           spies in disguise  Nick Bruno, Troy Quane
# 5856                                little women            Greta Gerwig
# 5857                                        1917              Sam Mendes
# 5858                                  just mercy   Destin Daniel Cretton
# 5859                                    clemency         Chinonye Chukwu
#
#                                         genres       actor_1_name  \
# ...

# %%
final_df.isnull().sum()
# Out:
# movie_title       0
# director_name     0
# genres            0
# actor_1_name      0
# actor_2_name     10
# actor_3_name     27
# comb             27
# dtype: int64

# %%
final_df.to_csv(path_dir+'/'+'final_data.csv',index=False)
